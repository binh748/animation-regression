# %% [markdown]
# ## Modeling global gross of Japanese v. American animated films ##

# %% [markdown]
# ### USA model ###

# %% [markdown]
# ![usa_baseline_model_visual.png](attachment:usa_baseline_model_visual.png)
#
# Notes: Not a bad baseline model. There is some multi-collinearity that I need to address, but nothing that seems too difficult to sort out. Need to start on feature engineering, especially to improve modeling of higher gross animated films.
#
# **Training R^2 score:     0.703**
# **Validation R^2 score:     0.624**
#
# **Feature coefficients:**
#
# runtime_minutes:           2373579.49
# budget:                    2.41
# years_since_release:       -280946.33
# imdb_user_rating:          14458810.43
# imdb_user_rating_count:    724.63
# oscar_wins:                56910264.74
# non_oscar_wins:            -406787.89
# metascore:                 -1556755.77

# %% [markdown]
# ### Japan model ###

# %% [markdown]
# ![japan_baseline_model_visual.png](attachment:japan_baseline_model_visual.png)
#
# Notes: Baseline model is very underfit. Need to do a lot of work here to improve R^2 and address multi-collinearity issues.
#
# **Training R^2 score:       0.406**
# **Validation R^2 score:     0.583**
#
# **Feature coefficients:**
#
# runtime_minutes:           35317.85
# budget:                    0.22
# years_since_release:       -327957.58
# imdb_user_rating:          -1692866.49
# imdb_user_rating_count:    326.98
# oscar_wins:                0.00
# non_oscar_wins:            4940920.46
# metascore:                 -240402.37
